# %% [markdown]
# This notebook goes through how to define a **custom modification** and apply it to some **geometry**.

# %% [markdown]
# # IMPORTS

# %%
import matplotlib.pyplot as plt

from spomso.cores.helper_functions import generate_grid, smarter_reshape
from spomso.cores.post_processing import hard_binarization
from spomso.cores.geom_2d import Circle

# %% [markdown]
# # PARAMETERS

# %%
# size of the volume
co_size = 4, 4
# resolution of the volume
co_resolution = 400, 400

show = "FIELD" # BINARY, FIELD
show_midplane = True

# %% [markdown]
# # COORDINATE SYSTEM

# %% [markdown]
# Point cloud of coordinates is created with the **generate_grid** function, which takes the size of the coordinate system and the number of points in each direction (**co_resolution**).

# %%
coor, co_res_new = generate_grid(co_size, co_resolution)

# %% [markdown]
# If there is an even number of points along any direction the function will automatically convert it to an odd number, therefore the origin is always included in the point cloud. The point cloud is a numpy.ndarray with a shape of **(D, N)**, where **D** is the number of dimensions and **N** is the number of data points.

# %% [markdown]
# # CREATE SDFs

# %% [markdown]
# Create a **circle** with radius of 0.5

# %%
circle = Circle(0.5)

# %% [markdown]
# Define the **custom modification** as a function:

# %%
def move_along_vector(sdf_, co_cloud_, sdf_params_, vector):
    q = co_cloud_.copy()
    q[0] -= vector[0]
    q[1] -= vector[1]

    return sdf_(q, sdf_params_)

# %% [markdown]
# In this case the **custom_modification** is the same as the **move** transformation.
# The only parameter is the **vector** by which the center of the **SDF** is moved.

# %% [markdown]
# Apply the **custom modification** to the **circle**, which will move it for **0.5** units in the x-axis and **1.0** units in the y-axis.
# The **custom modification** is name "move_along_vector".

# %%
circle.custom_modification(move_along_vector, (0.5, 1.0, 0.0), modification_name="move_along_vector")
# Out:
# <function spomso.cores.modifications.ModifyObject.custom_modification.<locals>.new_geo_object(co, *params)>

# %% [markdown]
# ## EVALUATE

# %% [markdown]
# Evaluate the SDF of the **circle** to create a signed distance field 2D map. This is done by calling the **create** method and passing in the point cloud of coordinates:

# %%
circle_pattern = circle.create(coor)

# %% [markdown]
# # BINARIZATION

# %% [markdown]
# Convert the distance field to a binary voxel map, where 1 corresponds to the interior and 0 to the exterior of the geometry.

# %%
if show_midplane:
    field = smarter_reshape(circle_pattern, co_resolution)
    if show=="BINARY":
        pattern_2d = hard_binarization(field, 0)

# %% [markdown]
# # PLOT

# %%
print("Drawing results...")
# Mid-plane cross-section plot
if show_midplane and show=="BINARY":
    fig, ax = plt.subplots(1,1, figsize=(8.25, 8.25))
    ax.imshow(pattern_2d[:, :].T,
              cmap="binary_r",
              extent=(-co_size[0]/2, co_size[0]/2,
                      -co_size[1]/2, co_size[1]/2),
              origin="lower"
              )
    ax.grid()

    fig.tight_layout()
    plt.show()

if show_midplane and show == "FIELD":
    fig, ax = plt.subplots(1, 1, figsize=(8.25, 8.25))
    print(field.shape)
    ax.imshow(field[:, :].T,
              cmap="binary_r",
              extent=(-co_size[0] / 2, co_size[0] / 2,
                      -co_size[1] / 2, co_size[1] / 2),
              origin="lower"
              )
    cs = ax.contour(coor[0].reshape(co_res_new[0], co_res_new[1]),
                    coor[1].reshape(co_res_new[0], co_res_new[1]),
                    field[:, :],
                    cmap="plasma_r")
    ax.clabel(cs, inline=True, fontsize=10)
    ax.grid()
# Out:
# Drawing results...
# (401, 401)
